# %%
import urllib.request #Handling URL
from bs4 import BeautifulSoup  #HAndle parsing html files
import nltk
import matplotlib.pyplot as plt


nltk.download( 'stopwords') #is was extract
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
response = urllib.request.urlopen('https://en.wikipedia.org/wiki/Mahendra')
html = response.read()
#it is difficult to read html file thats why we use parsing
#using html5lib
soup = BeautifulSoup(html, 'html5lib')
text = soup.get_text(strip = True)

# %%
tokens = [ t for t in text.split()]

sr = stopwords.words('english')
clean_tokens = tokens[:]

# %%
for token in tokens:
    if token in stopwords.words('english'):
        clean_tokens.remove(token)

freq = nltk.FreqDist(clean_tokens)
for key, val in freq.items():
    print(str(key) + ':'+ str(val))
# Out:
# Mahendra:1
# -:1
# Wikipedia(function(){var:1
# className="client-js:1
# vector-feature-language-in-header-enabled:1
# vector-feature-language-in-main-page-header-disabled:1
# vector-feature-sticky-header-disabled:1
# vector-feature-page-tools-pinned-disabled:1
# vector-feature-toc-pinned-clientpref-1:1
# vector-feature-main-menu-pinned-disabled:1
# vector-feature-limited-width-clientpref-1:1
# vector-feature-limited-width-content-enabled:1
# vector-feature-custom-font-size-clientpref-1:1
# vector-feature-appearance-pinned-clientpref-1:1
# vector-feature-night-mode-enabled:1
# skin-theme-clientpref-day:1
# vector-toc-available";var:1
# cookie=document.cookie.match(/(?:^|;:1
# )enwikimwclientpreferences=([^;]+)/);if(cookie){cookie[1].split('%2C').forEach(function(pref){className=className.replace(new:1
# RegExp('(^|:1
# )'+pref.replace(/-clientpref-\w+$|[^\w-]+/g,'')+'-clientpref-\\w+(:1
# |$)'),'$1'+pref+'$2');});}document.documentElement.className=className;}());RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy",:1
# "wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"88d7f0c2-ddf1-42a7-9bee-2d1a00dbdb9e","wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Mahendra","wgTitle":"Mahendra","wgCurRevisionId":1260414062,"wgRevisionId":1260414062,"wgArticleId":382235,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles:1
# short:2
# description","Short:1
# description:2
# different:2
# Wikidata","Use:1
# dmy:2
# dates:2
# December:3
# 2013","Articles:1
# containing:2
# Sanskrit-language:2
# text","Indian:1
# masculine:3
# given:5
# names","Masculine:1
# names"],"wgPageViewLanguage":"en","wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Mahendra","wgRelevantArticleId":382235,"wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgNoticeProject"::1
# "wikipedia","wgCiteReferencePreviewsActive":false,"wgFlaggedRevsParams":{"tags":{"status":{"levels":1}}},"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":0,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":true,"watchlist":true,"tagline":false,"nearby":true},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":2000,"wgRelatedArticlesCompat":[],"wgEditSubmitButtonLabelPublish":true,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":false,"wgVector2022LanguageInHeader":true,"wgULSisLanguageSelectorEmpty":false,"wgWikibaseItemId":"Q6733720","wgCheckUserClientHintsHeadersJsApi":["brands","architecture","bitness","fullVersionList","mobile","model","platform","platformVersion"],"GEHomepageSuggestedEditsEnableTopics":true,"wgGETopicsMatchModeEnabled":false,"wgGEStructuredTaskRejectionReasonTextInputEnabled":false,"wgGELevelingUpEnabledForUser":false};:1
# RLSTATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","skins.vector.search.codex.styles":"ready","skins.vector.styles":"ready","skins.vector.icons":"ready","ext.wikimediamessages.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","wikibase.client.init":"ready","ext.wikimediaBadges":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.ready","mediawiki.toc","skins.vector.js","ext.centralNotice.geoIP","ext.centralNotice.startUp","ext.gadget.ReferenceTooltips","ext.gadget.switcher","ext.urlShortener.toolbar","ext.centralauth.centralautologin","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.echo.centralauth","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.interface","ext.cx.eventlogging.campaigns",:1
# "ext.cx.uls.quick.actions","wikibase.client.vector-2022","ext.checkUser.clientHints","ext.growthExperiments.SuggestedEditSession"];(RLQ=window.RLQ||[]).push(function(){mw.loader.impl(function(){return["user.options@12s5i",function($,jQuery,require,module){mw.user.tokens.set({"patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});:1
# }];});});Jump:1
# contentMain:1
# menuMain:1
# menumove:1
# sidebarhideNavigationMain:1
# pageContentsCurrent:1
# eventsRandom:1
# articleAbout:1
# WikipediaContact:1
# usContributeHelpLearn:1
# editCommunity:1
# portalRecent:1
# changesUpload:2
# fileSearchSearchAppearanceDonateCreate:1
# accountLog:2
# inPersonal:1
# toolsDonateCreate:1
# inPages:1
# logged:1
# editorslearn:1
# moreContributionsTalkContentsmove:1
# sidebarhide(Top)1History:1
# politicsToggle:1
# History:1
# politics:1
# subsection1.1Royalty1.2Elected:1
# office2EntertainmentToggle:1
# Entertainment:1
# subsection2.1Film2.2Music2.3Sports3Business4See:1
# also5ReferencesToggle:1
# .references{font-size:100%;margin-bottom:0;list-style-type:inherit}.mw-parser-output:1
# .reflist-columns-2{column-width:30em}.mw-parser-output:1
# .reflist-columns-3{column-width:25em}.mw-parser-output:1
# .reflist-columns{margin-top:0.3em}.mw-parser-output:1
# .reflist-columns:2
# ol{margin-top:0}.mw-parser-output:1
# li{page-break-inside:avoid;break-inside:avoid-column}.mw-parser-output:1
# .reflist-upper-alpha{list-style-type:upper-alpha}.mw-parser-output:1
# .reflist-upper-roman{list-style-type:upper-roman}.mw-parser-output:1
# .reflist-lower-alpha{list-style-type:lower-alpha}.mw-parser-output:1
# .reflist-lower-greek{list-style-type:lower-greek}.mw-parser-output:1
# .reflist-lower-roman{list-style-type:lower-roman}^.mw-parser-output:1
# cite.citation{font-style:inherit;word-wrap:break-word}.mw-parser-output:1
# .citation:2
# q{quotes:"\"""\"""'""'"}.mw-parser-output:1
# .citation:target{background-color:rgba(0,127,255,0.133)}.mw-parser-output:1
# .id-lock-free.id-lock-free:1
# a{background:url("//upload.wikimedia.org/wikipedia/commons/6/65/Lock-green.svg")right:1
# 0.1em:4
# center/9px:3
# no-repeat}.mw-parser-output:3
# .id-lock-limited.id-lock-limited:1
# a,.mw-parser-output:1
# .id-lock-registration.id-lock-registration:1
# a{background:url("//upload.wikimedia.org/wikipedia/commons/d/d6/Lock-gray-alt-2.svg")right:1
# .id-lock-subscription.id-lock-subscription:1
# a{background:url("//upload.wikimedia.org/wikipedia/commons/a/aa/Lock-red-alt-2.svg")right:1
# .cs1-ws-icon:2
# a{background:url("//upload.wikimedia.org/wikipedia/commons/4/4c/Wikisource-logo.svg")right:1
# center/12px:1
# no-repeat}body:not(.skin-timeless):not(.skin-minerva):1
# .id-lock-free:1
# a,body:not(.skin-timeless):not(.skin-minerva):4
# .id-lock-limited:1
# .id-lock-registration:1
# .id-lock-subscription:1
# a{background-size:contain;padding:0:1
# 1em:1
# 0:1
# 0}.mw-parser-output:1
# .cs1-code{color:inherit;background:inherit;border:none;padding:inherit}.mw-parser-output:1
# .cs1-hidden-error{display:none;color:var(--color-error,#d33)}.mw-parser-output:1
# .cs1-visible-error{color:var(--color-error,#d33)}.mw-parser-output:1
# .cs1-maint{display:none;color:#085;margin-left:0.3em}.mw-parser-output:1
# .cs1-kern-left{padding-left:0.2em}.mw-parser-output:1
# .cs1-kern-right{padding-right:0.2em}.mw-parser-output:1
# .mw-selflink{font-weight:inherit}@media:1
# .cs1-format{font-size:95%}html.skin-theme-clientpref-night:1
# .cs1-maint{color:#18911f}}@media:1
# screen:1
# (prefers-color-scheme:dark){html.skin-theme-clientpref-os:1
# .cs1-maint{color:#18911f}}"Mahendra,:1
# Māhendra,:1
# Mahemdra,:1
# Maha-indra::1
# 49:1
# definitions".wisdomlib.org.:1
# 19:1
# 2011.:1
# Retrieved10:1
# April2023.Retrieved:1
# "https://en.wikipedia.org/w/index.php?title=Mahendra&oldid=1260414062"Categories:Indian:1
# namesMasculine:1
# namesHidden:1
# categories:Articles:1
# descriptionShort:1
# WikidataUse:1
# 2013Articles:1
# textThis:1
# page:1
# last:1
# edited:1
# 30:1
# November:1
# 2024,:1
# 16:58(UTC).Text:1
# available:1
# theCreative:1
# Commons:1
# Attribution-ShareAlike:1
# 4.0:1
# License;:1
# additional:1
# terms:1
# may:1
# apply.:1
# By:1
# using:1
# site,:1
# agree:1
# theTerms:1
# UseandPrivacy:1
# Policy.:1
# Wikipedia®:1
# registered:1
# trademark:1
# theWikimedia:1
# Foundation,:2
# Inc.,:1
# non-profit:1
# organization.Privacy:1
# policyAbout:1
# WikipediaDisclaimersContact:1
# WikipediaCode:1
# ConductDevelopersStatisticsCookie:1
# statementMobile:1
# view(RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgHostname":"mw-web.codfw.main-59ccf9db48-527sz","wgBackendResponseTime":137,"wgPageParseReport":{"limitreport":{"cputime":"0.209","walltime":"0.293","ppvisitednodes":{"value":423,"limit":1000000},"postexpandincludesize":{"value":4258,"limit":2097152},"templateargumentsize":{"value":698,"limit":2097152},"expansiondepth":{"value":12,"limit":100},"expensivefunctioncount":{"value":5,"limit":500},"unstrip-depth":{"value":1,"limit":20},"unstrip-size":{"value":4679,"limit":5000000},"entityaccesscount":{"value":0,"limit":400},"timingprofile":["100.00%:1
# 278.268:1
# 1:8
# -total",":1
# 39.05%:1
# 108.661:1
# Template:Langx",":1
# 28.10%:1
# 78.189:1
# Template:Reflist",":1
# 24.06%:1
# 66.949:1
# Template:Cite_web",":1
# 20.10%:1
# 55.918:1
# Template:Short_description",":1
# 11.37%:1
# 31.630:1
# 2:1
# Template:Pagetype",":1
# 7.54%:1
# 20.970:1
# Template:Distinguish",":1
# 5.32%:1
# 14.790:1
# 4:1
# Template:Main_other",":1
# 4.56%:1
# 12.697:1
# Template:Use_dmy_dates",":1
# 4.41%:1
# 12.268:1
# Template:SDcat"]},"scribunto":{"limitreport-timeusage":{"value":"0.153","limit":"10.000"},"limitreport-memusage":{"value":14297959,"limit":52428800}},"cachereport":{"origin":"mw-web.codfw.main-59ccf9db48-c8nhh","timestamp":"20250104170056","ttl":2592000,"transientcontent":false}}});});{"@context":"https:\/\/schema.org","@type":"Article","name":"Mahendra","url":"https:\/\/en.wikipedia.org\/wiki\/Mahendra","sameAs":"http:\/\/www.wikidata.org\/entity\/Q6733720","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q6733720","author":{"@type":"Organization","name":"Contributors:1
# Wikimedia:1
# projects"},"publisher":{"@type":"Organization","name":"Wikimedia:1
# Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2003-11-28T21:18:24Z","dateModified":"2024-11-30T16:58:31Z","headline":"male:1
# name"}:1

# %%
freq.plot(20, cumulative = False)
print(freq.most_common(20))
# Out:
# [('.mw-parser-output', 8), ('1', 8), ('given', 5), ('king', 4), ('Indian', 4), ('0.1em', 4), ('a,body:not(.skin-timeless):not(.skin-minerva)', 4), ('December', 3), ('masculine', 3), ('center/9px', 3), ('no-repeat}.mw-parser-output', 3), ('short', 2), ('description', 2), ('different', 2), ('dmy', 2), ('dates', 2), ('containing', 2), ('Sanskrit-language', 2), ('changesUpload', 2), ('accountLog', 2)]
